# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Simulate self-affine 1d vector

# %%
# parameters
#####################
dx = 1 # grid spacing
nx = 1000 # length in time units 
hurst = 0.5
seed = 420

def nextpow2(num):
    pow2 = 2
    while pow2 <= num:
        pow2 = pow2 * 2
    return pow2

def generate_colored_noise(hurst, nx, dx, seed=None):
    np.random.seed(seed=seed)
    beta = -2*(hurst+0.5)
    print('power law exponent: {}'.format(beta))
    # power -> amplitude
    beta = 0.5*beta
    n1n = nextpow2(np.rint(nx/dx))
    # radial wavenumber components
    dk1 = (1./n1n)*(2*np.pi/dx)
    knyq = np.pi / dx
    k1 = np.fft.fftshift(dk1*np.linspace(-n1n/2-1,n1n/2,n1n))
    kr = np.sqrt(k1**2)
    ampspec = kr**beta
    # simulate power law
    rf1d = ampspec*(np.random.randn(n1n)+1j*np.random.randn(n1n))
    # inverse transform; deman for fun
    rf1d = np.real(np.fft.ifft(rf1d))-mean(rf1d)
    return rf1d

# %%
plot(rf1d)
# Out:
# power law exponent: -2.0
# /Users/wsavran/Applications/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
